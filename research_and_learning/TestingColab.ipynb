# %%
print("Hi")
# Out:
# Hi

# %%
print(2+4+5)
# Out:
# 11

# %% [markdown]
# # New section

# %%
import pandas as pd
import numpy as np

s = pd.Series([1,3,np.nan,"madhu"])

# %%
s
# Out:
# 0        1
# 1        3
# 2      NaN
# 3    madhu
# dtype: object

# %%
pd.read_csv("/content/sample_data/california_housing_test.csv")
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 1       -118.30     34.26  ...         3.5990            176500.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 3       -118.36     33.82  ...         6.1359            330000.0
# 4       -119.67     36.33  ...         2.9375             81700.0
# ...         ...       ...  ...            ...                 ...
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv').tail(15)
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 2985    -120.47     34.94  ...         1.8633            109400.0
# 2986    -118.25     33.93  ...         1.1346             85400.0
# 2987    -121.97     37.29  ...         5.3294            300300.0
# 2988    -122.01     36.97  ...         2.5417            260900.0
# 2989    -122.02     37.60  ...         3.2386            149600.0
# 2990    -118.23     34.09  ...         2.6923            150000.0
# 2991    -117.17     34.28  ...         7.1997            253800.0
# 2992    -122.33     37.39  ...         6.2263            500001.0
# 2993    -117.91     33.60  ...         5.1048            500001.0
# 2994    -117.93     33.86  ...         5.5867            182500.0
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# ...

# %%
x = range(3)

# %%
x
# Out:
# range(0, 3)

# %%
print(x)
# Out:
# range(0, 3)

# %%
for i in x:
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
x =  [["even"+" "+str(i) for i in range(7) if i%2==0],["odd"+" "+str(i) for i in range(7) if i%2!=0]]

# %%
x
# Out:
# [['even 0', 'even 2', 'even 4', 'even 6'], ['odd 1', 'odd 3', 'odd 5']]

# %%
for i in x:
  print(i)
# Out:
# ['even 0', 'even 2', 'even 4', 'even 6']
# ['odd 1', 'odd 3', 'odd 5']

# %%
x_even,x_odd = x[0],x[1]

# %%
x_even
# Out:
# ['even 0', 'even 2', 'even 4', 'even 6']

# %%
for i in x_even+x_odd:
  print(i)
# Out:
# even 0
# even 2
# even 4
# even 6
# odd 1
# odd 3
# odd 5

# %%
x_final=[]
for i in x_even+x_odd:
  x_final.append(i)

# %%
x_sort = sorted(x_final, key=lambda a:a.split(" ")[-1])

# %%
x_sort
# Out:
# ['even 0', 'odd 1', 'even 2', 'odd 3', 'even 4', 'odd 5', 'even 6']

# %%
l = len(x_sort)
for i in x_sort:
  # print(type(i.split(" ")[-1]))
  # print(l-1)
  if int(i.split(" ")[-1])==l-1:
    print(i)
  else:
    print(i,end=",\n")
# Out:
# even 0,
# odd 1,
# even 2,
# odd 3,
# even 4,
# odd 5,
# even 6

# %%
l
# Out:
# [1, 2, 3, 5, 7, 9]

# %%
l=[1,1,2,3,1,2,3,5,7,7,9,"madhu","madhu"]
for i in l:
  if l.count(i)>=2:
    l.remove(i)
    # print("after removed",i,"in", l)

# %%
l
# Out:
# [1, 2, 3, 5, 7, 9, 'madhu']

# %%
def fun(x):
  if isinstance(x,str):
    return "Input Shouldn't be Character Type"
  else:
    return x+10
print(fun("madhu"))
# Out:
# Input Shouldn't be Character Type

# %%
def mad():
  a=10
  b=12
  c=30
  return locals()

# %%
print(mad())
# Out:
# {'c': 30, 'b': 12, 'a': 10}

# %%
def mad():
  a,*b=[1,2,3,4,6]
  return locals()

# %%
print(mad())
# Out:
# {'b': [2, 3, 4, 6], 'a': 1}

# %%
print(callable(mad))
# Out:
# True

# %%
l
# Out:
# [1, 2, 3, 5, 7, 9, 'madhu']

# %%
iter_l = iter(l)

# %%
while True:
  try:
    print(next(iter_l))
  except:
    break
# Out:
# 1
# 2
# 3
# 5
# 7
# 9
# madhu

# %%
import csv

# %%
with open("/content/sample_data/california_housing_test.csv") as file:
  csv_reader = csv.DictReader(file,delimiter=',')

  while True:
    i=next(csv_reader)
    print(i['longitude'])
    break
# Out:
# -122.050000

# %%
b= bytearray('ABC','utf-8')
print(b[0])
mv = memoryview(b)
list(mv)
# Out:
# 65
# [65, 66, 67]

# %%
x = reversed(list('Madhusudhan Reddy'))
for i in x:
  print(i)
  break
# Out:
# y

# %%
import itertools

# %%
print(itertools.count(10,5))
# Out:
# count(10, 5)

# %%
for i in itertools.cycle("10"):
  print(i)
  break
# Out:
# 1

# %%
import numpy as np
print(np)
# Out:
# <module 'numpy' from '/usr/local/lib/python3.6/dist-packages/numpy/__init__.py'>

# %%
array = np.array([[1,2,3,4],[2,3,4,5],[1,2,3,4]])

# %%
array
# Out:
# array([[1, 2, 3, 4],
#        [2, 3, 4, 5],
#        [1, 2, 3, 4]])

# %%
x=45

# %%
print(x>50)
# Out:
# False
