# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
# data from https://www.kaggle.com/c/titanic

# %%
df = pd.read_csv('/content/train.csv')

# %% [markdown]
# **How many persons are there in each cabin?**

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
cabin_grouped = df['PassengerId'].groupby(df['Cabin'])

# %%
cabin_grouped.sum()
# Out:
# Cabin
# A10       584
# A14       476
# A16       557
# A19       285
# A20       600
#         ...
# F38       777
# F4        803
# G6        864
# NaN    304484
# T         340
# Name: PassengerId, Length: 148, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.scatter(cabin_grouped,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-b33f9e145f62> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 y=[0*len(cabin_grouped)]
# ----> 3 plt.scatter(cabin_grouped,y)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...
