# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Series

# %%
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series(data=[1,2,3,4], index=['a', 'd', 'c', 'f'])
obj2
# Out:
# a    1
# d    2
# c    3
# f    4
# dtype: int64

# %%
obj2.index
# Out:
# Index(['a', 'd', 'c', 'f'], dtype='object')

# %%
obj2[['a','c','d']]
# Out:
# a    1
# c    3
# d    2
# dtype: int64

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['a', 'b', 'a', 'c'])
obj2['a'] # or obj2.a
# Out:
# a    4
# a   -5
# dtype: int64

# %%
obj2['b']
# Out:
# 7

# %%
obj2['a'] = 12
obj2['a']
# Out:
# a    12
# a    12
# dtype: int64

# %%
index = np.arange(len(obj2))
obj2.index = index

# %%
obj2
# Out:
# 0    12
# 1     7
# 2    12
# 3     3
# dtype: int64

# %%
obj2[[1,3,2]]
# Out:
# 1     7
# 3     3
# 2    12
# dtype: int64

# %%
obj2
# Out:
# 0    12
# 1     7
# 2    12
# 3     3
# dtype: int64

# %%
#operations
obj2[obj2>10]
# Out:
# 0    12
# 2    12
# dtype: int64

# %%
obj2*2
# Out:
# 0    24
# 1    14
# 2    24
# 3     6
# dtype: int64

# %%
obj2*np.exp(2)
# Out:
# 0    88.668673
# 1    51.723393
# 2    88.668673
# 3    22.167168
# dtype: float64

# %%
0 in obj2 # it will check keys(indexes)
# Out:
# True

# %%
88.668673 in obj2
# Out:
# False

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj3.index = states
obj3
# Out:
# California    35000
# Ohio          71000
# Oregon        16000
# Texas          5000
# dtype: int64

# %%
obj4 = pd.Series(data=sdata, index=states)  # if indexes and data of keys don't match then thier value set as NaN
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj4.isnull()
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj4.notnull()
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %% [markdown]
# ##DataFrame

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

frame = pd.DataFrame(data=data, index=np.arange(len(data['state'])))

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.name = "population"
frame.index.name = "Index"

# %%
frame
# Out:
#         state  year  pop
# Index
# 0        Ohio  2000  1.5
# 1        Ohio  2001  1.7
# 2        Ohio  2002  3.6
# 3      Nevada  2001  2.4
# 4      Nevada  2002  2.9
# 5      Nevada  2003  3.2

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   state   6 non-null      object
#  1   year    6 non-null      int64
#  2   pop     6 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 192.0+ bytes

# %%
frame.describe().T
# Out:
#       count     mean       std     min       25%      50%       75%     max
# year    6.0  2001.50  1.048809  2000.0  2001.000  2001.50  2002.000  2003.0
# pop     6.0     2.55  0.836062     1.5     1.875     2.65     3.125     3.6

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

frame = pd.DataFrame(data=data, columns=['year', 'state', 'pop'])

# %%
frame
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
#if you pass column name that is not appeared in data, that column set to be NaN
frame2 = pd.DataFrame(data=data, columns=['year', 'state', 'pop', 'debt'])
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
#accessing column data
frame2.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
frame2['pop']
# Out:
# 0    1.5
# 1    1.7
# 2    3.6
# 3    2.4
# 4    2.9
# 5    3.2
# Name: pop, dtype: float64

# %%
#accessing row data

frame2.loc[3]
# Out:
# year       2001
# state    Nevada
# pop         2.4
# debt        NaN
# Name: 3, dtype: object

# %%
frame2['debt'] = 16.5

# %%
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5  16.5
# 1  2001    Ohio  1.7  16.5
# 2  2002    Ohio  3.6  16.5
# 3  2001  Nevada  2.4  16.5
# 4  2002  Nevada  2.9  16.5
# 5  2003  Nevada  3.2  16.5

# %%
frame2['debt'] = np.arange(6.)

# %%
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5   0.0
# 1  2001    Ohio  1.7   1.0
# 2  2002    Ohio  3.6   2.0
# 3  2001  Nevada  2.4   3.0
# 4  2002  Nevada  2.9   4.0
# 5  2003  Nevada  3.2   5.0

# %%
series = pd.Series(data=[1,-.4,'madhu'], index = [0,4,2])
frame2['debt'] = series

# %%
frame2
# Out:
#    year   state  pop   debt
# 0  2000    Ohio  1.5      1
# 1  2001    Ohio  1.7    NaN
# 2  2002    Ohio  3.6  madhu
# 3  2001  Nevada  2.4    NaN
# 4  2002  Nevada  2.9   -0.4
# 5  2003  Nevada  3.2    NaN

# %%
frame2['debt'] = frame2['state'] == 'Ohio' 
frame2['pop < avg'] = (frame2['pop'] <= (sum(frame2['pop'])/len(frame2['pop'])))

# %%
frame2
# Out:
#    year   state  pop   debt  pop < avg
# 0  2000    Ohio  1.5   True       True
# 1  2001    Ohio  1.7   True       True
# 2  2002    Ohio  3.6   True      False
# 3  2001  Nevada  2.4  False       True
# 4  2002  Nevada  2.9  False      False
# 5  2003  Nevada  3.2  False      False

# %%
frame2
# Out:
#    year   state  pop   debt  pop < avg
# 0  2000    Ohio  1.5   True       True
# 1  2001    Ohio  1.7   True       True
# 2  2002    Ohio  3.6   True      False
# 3  2001  Nevada  2.4  False       True
# 4  2002  Nevada  2.9  False      False
# 5  2003  Nevada  3.2  False      False

# %%
frame2.drop('pop < avg', axis=1, inplace=True)
frame2
# Out:
#    year   state  pop   debt
# 0  2000    Ohio  1.5   True
# 1  2001    Ohio  1.7   True
# 2  2002    Ohio  3.6   True
# 3  2001  Nevada  2.4  False
# 4  2002  Nevada  2.9  False
# 5  2003  Nevada  3.2  False

# %%
frame2+frame
# Out:
#    debt  pop         state  year
# 0   NaN  3.0      OhioOhio  4000
# 1   NaN  3.4      OhioOhio  4002
# 2   NaN  7.2      OhioOhio  4004
# 3   NaN  4.8  NevadaNevada  4002
# 4   NaN  5.8  NevadaNevada  4004
# 5   NaN  6.4  NevadaNevada  4006

# %%
frame2.append(frame)
# Out:
#    year   state  pop   debt
# 0  2000    Ohio  1.5   True
# 1  2001    Ohio  1.7   True
# 2  2002    Ohio  3.6   True
# 3  2001  Nevada  2.4  False
# 4  2002  Nevada  2.9  False
# 5  2003  Nevada  3.2  False
# 0  2000    Ohio  1.5    NaN
# 1  2001    Ohio  1.7    NaN
# 2  2002    Ohio  3.6    NaN
# 3  2001  Nevada  2.4    NaN
# 4  2002  Nevada  2.9    NaN
# 5  2003  Nevada  3.2    NaN

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0, 2, 4])
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
obj3.reindex(np.arange(6), method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),index=['a', 'c', 'd'],columns=['Ohio', 'Texas', 'California'])
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame2 = frame.reindex(['a','b','c','d'])
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),index=['Ohio', 'Colorado', 'Utah', 'New York'],columns=['one', 'two', 'three', 'four'])

data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.loc['Colorado']
# Out:
# one      4
# two      5
# three    6
# four     7
# Name: Colorado, dtype: int64

# %%
data.loc['Colorado', ['two', 'three']]
# Out:
# two      5
# three    6
# Name: Colorado, dtype: int64

# %%
data.loc[['Colorado','New York'], ['two','three']]
# Out:
#           two  three
# Colorado    5      6
# New York   13     14

# %%
data.loc['Colorado':'New York', 'two':'three']
# Out:
#           two  three
# Colorado    5      6
# Utah        9     10
# New York   13     14

# %%
data.iloc[:3, :2]
# Out:
#           one  two
# Ohio        0    1
# Colorado    4    5
# Utah        8    9

# %%
data.iloc[2, [3, 0, 1]]
# Out:
# four    11
# one      8
# two      9
# Name: Utah, dtype: int64

# %%
data.iloc[:, :3][data.three > 5]
# Out:
#           one  two  three
# Colorado    4    5      6
# Utah        8    9     10
# New York   12   13     14

# %%
## Functions applying betweeen mapping
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'),index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#                b         d         e
# Utah    1.862151  1.113199  0.018327
# Ohio    1.984844  0.045435  0.461091
# Texas  -1.389106 -0.630397  1.011137
# Oregon -0.678748 -1.072726  1.280971

# %%
np.abs(frame)
# Out:
#                b         d         e
# Utah    1.862151  1.113199  0.018327
# Ohio    1.984844  0.045435  0.461091
# Texas   1.389106  0.630397  1.011137
# Oregon  0.678748  1.072726  1.280971

# %%
frame
# Out:
#                b         d         e
# Utah    1.862151  1.113199  0.018327
# Ohio    1.984844  0.045435  0.461091
# Texas  -1.389106 -0.630397  1.011137
# Oregon -0.678748 -1.072726  1.280971

# %%
f = lambda x: x.max() - x.min()
frame.apply(f)
# Out:
# b    3.373950
# d    2.185925
# e    1.262644
# dtype: float64

# %%
frame.apply(f, axis='columns')
# Out:
# Utah      1.843824
# Ohio      1.939409
# Texas     2.400243
# Oregon    2.353696
# dtype: float64

# %%
def f(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])

frame.apply(f)
# Out:
#             b         d         e
# min -1.389106 -1.072726  0.018327
# max  1.984844  1.113199  1.280971

# %%
format = lambda x : '%.2f' % x
frame.applymap(format)
# Out:
#             b      d     e
# Utah     1.86   1.11  0.02
# Ohio     1.98   0.05  0.46
# Texas   -1.39  -0.63  1.01
# Oregon  -0.68  -1.07  1.28

# %%
frame.columns = ['a', 'b', 'c']

# %%
frame
# Out:
#                a         b         c
# Utah    1.862151  1.113199  0.018327
# Ohio    1.984844  0.045435  0.461091
# Texas  -1.389106 -0.630397  1.011137
# Oregon -0.678748 -1.072726  1.280971

# %%
frame['a'].map(format)
# Out:
# Utah       1.86
# Ohio       1.98
# Texas     -1.39
# Oregon    -0.68
# Name: a, dtype: object

# %%
#sorting
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
                     index=['three', 'one'],columns=['d', 'a', 'b', 'c'])

frame.sort_index
# Out:
# <bound method DataFrame.sort_index of        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7>

# %%
frame.sort_index()
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame.sort_index(axis=1)
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_index(axis=1,ascending=False)
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %%
obj = pd.Series([4, 7, -3, 2])
obj.sort_values()
# Out:
# 2   -3
# 3    2
# 0    4
# 1    7
# dtype: int64

# %%
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj.sort_values()
# Out:
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# 1    NaN
# 3    NaN
# dtype: float64

# %%
frame = pd.DataFrame({'b': [4, 7, -3, 2], 'a': [0, 1, 0, 1]})
frame.sort_values(by='a')
# Out:
#    b  a
# 0  4  0
# 2 -3  0
# 1  7  1
# 3  2  1

# %%
frame.sort_values(by='b')
# Out:
#    b  a
# 2 -3  0
# 3  2  1
# 0  4  0
# 1  7  1

# %%
frame.sort_values(by=['a', 'b'])
# Out:
#    b  a
# 2 -3  0
# 0  4  0
# 3  2  1
# 1  7  1

# %%
frame.sort_values(by=['b', 'a'])
# Out:
#    b  a
# 2 -3  0
# 3  2  1
# 0  4  0
# 1  7  1

# %%
obj = pd.Series([7, -5, 7, 4, 2, 0, 4, 4,3])
obj.rank().sort_values()
# Out:
# 1    1.0
# 5    2.0
# 4    3.0
# 8    4.0
# 3    6.0
# 6    6.0
# 7    6.0
# 0    8.5
# 2    8.5
# dtype: float64

# %%
obj.rank(method='first')
# Out:
# 0    8.0
# 1    1.0
# 2    9.0
# 3    5.0
# 4    3.0
# 5    2.0
# 6    6.0
# 7    7.0
# 8    4.0
# dtype: float64

# %%
obj.rank(ascending=True, method='max')
# Out:
# 0    9.0
# 1    1.0
# 2    9.0
# 3    7.0
# 4    3.0
# 5    2.0
# 6    7.0
# 7    7.0
# 8    4.0
# dtype: float64

# %%
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],[np.nan, np.nan], [0.75, -1.3]],index=['a', 'b', 'c', 'd'],columns=['one', 'two'])

df.sum()
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df.sum(axis=1)
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
df.mean(axis=1, skipna=True)
# Out:
# a    1.400
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
df.mean(axis=1, skipna=False)
# Out:
# a      NaN
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
import pandas_datareader.data as web
all_data = {ticker: web.get_data_yahoo(ticker)
for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}
price = pd.DataFrame({ticker: data['Adj Close']
for ticker, data in all_data.items()})
volume = pd.DataFrame({ticker: data['Volume']
for ticker, data in all_data.items()})

# %%
returns = price.pct_change()

# %%
returns.tail()
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2021-06-24 -0.002169  0.005740  0.005353  0.006488
# 2021-06-25 -0.002249  0.009626 -0.006262 -0.002255
# 2021-06-28  0.012546 -0.010556  0.013961 -0.001382
# 2021-06-29  0.011500  0.001790  0.009973 -0.006316
# 2021-06-30  0.004621  0.007145 -0.001842 -0.005575

# %%
returns.shape
# Out:
# (1257, 4)

# %%
returns.corr()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  1.000000  0.442666  0.725905  0.658362
# IBM   0.442666  1.000000  0.523463  0.489032
# MSFT  0.725905  0.523463  1.000000  0.772874
# GOOG  0.658362  0.489032  0.772874  1.000000

# %%
returns.cov()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  0.000363  0.000138  0.000238  0.000211
# IBM   0.000138  0.000266  0.000147  0.000134
# MSFT  0.000238  0.000147  0.000296  0.000223
# GOOG  0.000211  0.000134  0.000223  0.000282

# %%
returns.corrwith(volume)
# Out:
# AAPL   -0.049997
# IBM    -0.097478
# MSFT   -0.045168
# GOOG   -0.108819
# dtype: float64

# %%
volume
# Out:
#                    AAPL        IBM        MSFT     GOOG
# Date
# 2016-07-05  110820800.0  2465200.0  24806400.0  1462600
# 2016-07-06  123796400.0  2569400.0  28167500.0  1411900
# 2016-07-07  100558400.0  2138400.0  19585200.0  1304200
# 2016-07-08  115648400.0  3040600.0  28391000.0  1575200
# 2016-07-11   95179600.0  2833700.0  22269200.0  1111800
# ...                 ...        ...         ...      ...
# 2021-06-24   68711000.0  3609700.0  21446900.0   946700
# 2021-06-25   70730700.0  3593500.0  25604200.0  1674200
# 2021-06-28   62111300.0  3888900.0  19590000.0  1405500
# 2021-06-29   64556100.0  2428500.0  19937800.0  1047500
# 2021-06-30   63195300.0  3244600.0  21652500.0  1200300
#
# [1257 rows x 4 columns]

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
obj.unique()
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
obj.value_counts().unique()
# Out:
# array([3, 2, 1])

# %%
pd.value_counts(obj.values, sort=False)
# Out:
# b    2
# d    1
# c    3
# a    3
# dtype: int64

# %%
mask = obj.isin(['b', 'c'])

# %%
mask
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
obj[mask]
# Out:
# 0    c
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object
