# %%
# li = [9,8,1,2,3,4,7,6,0,]
li = [-1, -2, -3, -4]


# max, sort

_2nd_max = 0
for i in li:
    if i > max:
        _2nd_max = max
        max = i
    else:
        if i >= _2nd_max:
            _2nd_max = i

print(_2nd_max)
# Out:
# -1

# %%
ip = "ThisIsASampleCode"
op = "This is a sample code"

# %%
final_op = ""

for i, char in enumerate(ip):

    if i == 0:
        final_op += str(char).upper()
    else:
        if ord(char) >= 65 and ord(char) <= 90:
            final_op += " "+str(char).lower()
        else:
            final_op += char
print(final_op)
# Out:
# This is a sample code
